# %% [markdown]
# # Model training
# The goal of is to train classification model thab will predict if the client will subscrive a term deposit. I will train a few models and compare it's results:
# 1. Models training
#     * Linear Regression
#     * KNN
#     * SVM
#     * Decision Tree
#     * Random Forest
#     * XGBoost
#     * Dense Neutral Network
# 2. Results comparison
# 3. Inference

# %% [markdown]
# ### Model training

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier 
from sklearn.metrics import accuracy_score, confusion_matrix, precision_recall_fscore_support, classification_report, precision_recall_curve, roc_auc_score, plot_roc_curve
from sklearn.model_selection import validation_curve, GridSearchCV
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
import warnings
warnings.filterwarnings("ignore")

# %%
# Read prepared training and test data
X_train = pd.read_csv("X_train_oversample.csv", index_col=0, header=None).to_numpy()
X_test= pd.read_csv("X_test.csv", index_col=0, header=None).to_numpy()
y_train = pd.read_csv("y_trainoversample.csv", index_col=0, header=None).to_numpy().flatten()
y_test = pd.read_csv("y_test.csv", index_col=0, header=None).to_numpy().flatten()

# %%
# Check sizes of read data
print(f"size of X_train: {X_train.shape}")
print(f"size of X_test: {X_test.shape}")
print(f"size of y_train: {y_train.shape}")
print(f"size of y_test: {y_test.shape}")
# Out:
# size of X_train: (65826, 27)
# size of X_test: (4119, 27)
# size of y_train: (65826,)
# size of y_test: (4119,)

# %% [markdown]
# It's imporant to properly choose metrics to asses the model. For each model I'll present the following metrics:  accuracy, precision, recall, Fscore, AUC, Confusion Matrix. I do not have knowledge, what are the exact requirements of the Business Case. I will assume that it is important to predict as many customers than will subscribe the product as possible and therefore focuss on choosing model with good recall and overall accuracy.

# %%
# Prepare a function presenting results
def results(y_test, y_pred):
  print("Accuracy: {0:0.3f}".format(accuracy_score(y_test, y_pred)))
  print("Precision: {0:0.3f}".format(precision_recall_fscore_support(y_test, y_pred, pos_label=1, average="binary")[0]))
  print("Recall: {0:0.3f}".format(precision_recall_fscore_support(y_test, y_pred, pos_label=1, average="binary")[1]))
  print("Fscore: {0:0.3f}".format(precision_recall_fscore_support(y_test, y_pred, pos_label=1, average="binary")[2]))
  print("AUC: {0:0.3f}".format(roc_auc_score(y_test, y_pred)))
  print("\nConfusion matrix:")
  return pd.crosstab(y_test, y_pred, rownames=["True"], colnames=["Predicted"], margins=True)

# %% [markdown]
# ### 1.1 Logistic Regression

# %%
# Legistic Regression model training
lr = LogisticRegression(random_state=2022).fit(X_train, y_train)
y_pred_lr = lr.predict(X_test)
results(y_test, y_pred_lr)
# Out:
# Accuracy: 0.832
# Precision: 0.374
# Recall: 0.647
# Fscore: 0.474
# AUC: 0.751
#
# Confusion matrix:
# Predicted     0    1   All
# True
# 0          3112  523  3635
# 1           171  313   484
# All        3283  836  4119

# %% [markdown]
# ### 1.2 K-Nearest Neighbors

# %%
# KNN model training
knn = KNeighborsClassifier().fit(X_train, y_train)
y_pred_knn = knn.predict(X_test)
results(y_test, y_pred_knn)
# Out:
# Accuracy: 0.787
# Precision: 0.292
# Recall: 0.573
# Fscore: 0.387
# AUC: 0.694
#
# Confusion matrix:
# Predicted     0    1   All
# True
# 0          2964  671  3635
# 1           206  277   483
# All        3170  948  4118

# %% [markdown]
# ### 1.3 SVM

# %%
sv = svm.SVC(random_state=2022).fit(X_train, y_train)
y_pred_svm = sv.predict(X_test)
results(y_test, y_pred_svm)
# Out:
# Accuracy: 0.843
# Precision: 0.389
# Recall: 0.594
# Fscore: 0.470
# AUC: 0.735
#
# Confusion matrix:
# Predicted     0    1   All
# True
# 0          3184  451  3635
# 1           196  287   483
# All        3380  738  4118

# %% [markdown]
# ### 1.4 Decision Tree

# %%
# Choose depth of decision tree using greed search
dto = DecisionTreeClassifier(random_state=2022)
param_grid = {'max_depth': [5, 10, 15, 20, 25, 30, 35, 40]}
grid_tree = GridSearchCV(dto, param_grid=param_grid, cv=3, scoring=['accuracy', 'recall'], refit='recall')
grid_tree.fit(X_train, y_train)
for i in np.arange(8):
  print(f"{grid_tree.cv_results_['params'][i]}: mean test accuracy: {grid_tree.cv_results_['mean_test_accuracy'][i]:.3f}, mean test recall: {grid_tree.cv_results_['mean_test_recall'][i]:.3f}")
# Out:
# {'max_depth': 5}: mean test accuracy: 0.759, mean test recall: 0.623
# {'max_depth': 10}: mean test accuracy: 0.850, mean test recall: 0.775
# {'max_depth': 15}: mean test accuracy: 0.878, mean test recall: 0.824
# {'max_depth': 20}: mean test accuracy: 0.889, mean test recall: 0.862
# {'max_depth': 25}: mean test accuracy: 0.891, mean test recall: 0.878
# {'max_depth': 30}: mean test accuracy: 0.890, mean test recall: 0.880
# {'max_depth': 35}: mean test accuracy: 0.890, mean test recall: 0.881
# {'max_depth': 40}: mean test accuracy: 0.890, mean test recall: 0.881

# %% [markdown]
# ##### Comment
# Similar results are obtained using depth of tree 30, 35, and 40, therefore I'll choose the simplest model out of those 3- depth 30

# %%
# Train model based on chosed max_depth and score it
dt = DecisionTreeClassifier(max_depth=30, random_state=2022)
dt.fit(X_train, y_train)
y_pred_dt = dt.predict(X_test)
results(y_test, y_pred_dt)
# Out:
# Accuracy: 0.845
# Precision: 0.333
# Recall: 0.325
# Fscore: 0.329
# AUC: 0.619
#
# Confusion matrix:
# Predicted     0    1   All
# True
# 0          3321  314  3635
# 1           326  157   483
# All        3647  471  4118

# %% [markdown]
# ### 1.5 Random Forest

# %%
# Choose parameters for random forest using Grid Search
rf= RandomForestClassifier(random_state=2022)
param_grid = {'max_depth': [6, 8, 10],
              'n_estimators': [20, 50, 100]}
grid_rf = GridSearchCV(rf, param_grid=param_grid, cv=3, scoring=['accuracy', 'recall'], refit='recall')
grid_rf.fit(X_train, y_train)
for i in np.arange(9):
  print(f"{grid_rf.cv_results_['params'][i]}: mean test accuracy: {grid_rf.cv_results_['mean_test_accuracy'][i]:.3f}, mean test recall: {grid_rf.cv_results_['mean_test_recall'][i]:.3f}")
# Out:
# {'max_depth': 6, 'n_estimators': 20}: mean test accuracy: 0.761, mean test recall: 0.650
# {'max_depth': 6, 'n_estimators': 50}: mean test accuracy: 0.758, mean test recall: 0.639
# {'max_depth': 6, 'n_estimators': 100}: mean test accuracy: 0.762, mean test recall: 0.640
# {'max_depth': 8, 'n_estimators': 20}: mean test accuracy: 0.790, mean test recall: 0.688
# {'max_depth': 8, 'n_estimators': 50}: mean test accuracy: 0.788, mean test recall: 0.683
# {'max_depth': 8, 'n_estimators': 100}: mean test accuracy: 0.784, mean test recall: 0.674
# {'max_depth': 10, 'n_estimators': 20}: mean test accuracy: 0.813, mean test recall: 0.723
# {'max_depth': 10, 'n_estimators': 50}: mean test accuracy: 0.814, mean test recall: 0.724
# {'max_depth': 10, 'n_estimators': 100}: mean test accuracy: 0.817, mean test recall: 0.730

# %%
# Train model using chosen hyperparamters
rf = RandomForestClassifier(max_depth=10, n_estimators=100, random_state=2022)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)
results(y_test, y_pred_rf)
# Out:
# Accuracy: 0.869
# Precision: 0.454
# Recall: 0.563
# Fscore: 0.503
# AUC: 0.737
#
# Confusion matrix:
# Predicted     0    1   All
# True
# 0          3308  327  3635
# 1           211  272   483
# All        3519  599  4118

# %% [markdown]
# #### 1.6 LightGBoost

# %%
# Choose parameters for random forest using Grid Search
lgb = LGBMClassifier(random_state=2022, n_jobs=-1)
param_grid = {'max_depth': [3, 5, 7, 10, 20],
              'n_estimators': [100, 200, 300],
              'learning_rate': [0.1, 0.2, 0.3]}
grid_lgb = GridSearchCV(lgb, param_grid=param_grid, cv=3, scoring=['accuracy', 'recall'], refit='recall')
grid_lgb.fit(X_train, y_train)
grid_lgb.best_params_

# %%
# Train model using chosen hyperparamter
lgb = LGBMClassifier(max_depth=5, n_estimators=150, learning_rate=0.3, random_state=2022)
lgb.fit(X_train, y_train)
y_pred_xgb = lgb.predict(X_test)
results(y_test, y_pred_xgb)
# Out:
# Accuracy: 0.893
# Precision: 0.578
# Recall: 0.331
# Fscore: 0.421
# AUC: 0.650
#
# Confusion matrix:
# Predicted     0    1   All
# True
# 0          3518  117  3635
# 1           323  160   483
# All        3841  277  4118

# %% [markdown]
# #### 1.7 Dense Neural Network

# %%
def sequential_model():
  model = Sequential()
  model.add(Dense(64, activation='relu'))
  model.add(Dense(32, activation='relu'))
  model.add(Dense(16, activation='relu'))
  model.add(Dense(1, activation='sigmoid'))
  model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
  return model
 
dn = KerasClassifier(build_fn=sequential_model, epochs=100, batch_size=10, verbose=1)
dn.fit(X_train, y_train)
y_pred_dn = dn.predict(X_test).flatten()
results(y_test, y_pred_dn)
# Out:
# Epoch 1/100
# 6583/6583 [==============================] - 7s 983us/step - loss: 0.5260 - accuracy: 0.7437
# Epoch 2/100
# 6583/6583 [==============================] - 6s 970us/step - loss: 0.4979 - accuracy: 0.7570
# Epoch 3/100
# 6583/6583 [==============================] - 10s 2ms/step - loss: 0.4808 - accuracy: 0.7679
# Epoch 4/100
# 6583/6583 [==============================] - 10s 1ms/step - loss: 0.4667 - accuracy: 0.7736
# Epoch 5/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.4559 - accuracy: 0.7796
# Epoch 6/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.4460 - accuracy: 0.7855
# Epoch 7/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.4373 - accuracy: 0.7883
# Epoch 8/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.4304 - accuracy: 0.7916
# Epoch 9/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.4242 - accuracy: 0.7968
# Epoch 10/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.4184 - accuracy: 0.8006
# Epoch 11/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.4144 - accuracy: 0.8033
# Epoch 12/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.4092 - accuracy: 0.8060
# Epoch 13/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.4053 - accuracy: 0.8071
# Epoch 14/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.4015 - accuracy: 0.8125
# Epoch 15/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.3984 - accuracy: 0.8117
# Epoch 16/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.3933 - accuracy: 0.8152
# Epoch 17/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.3909 - accuracy: 0.8174
# Epoch 18/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.3883 - accuracy: 0.8168
# Epoch 19/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.3859 - accuracy: 0.8198
# Epoch 20/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.3827 - accuracy: 0.8193
# Epoch 21/100
# 6583/6583 [==============================] - 10s 2ms/step - loss: 0.3809 - accuracy: 0.8236
# Epoch 22/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.3786 - accuracy: 0.8231
# Epoch 23/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.3775 - accuracy: 0.8242
# Epoch 24/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.3735 - accuracy: 0.8260
# Epoch 25/100
# 6583/6583 [==============================] - 10s 2ms/step - loss: 0.3710 - accuracy: 0.8290
# Epoch 26/100
# 6583/6583 [==============================] - 10s 1ms/step - loss: 0.3687 - accuracy: 0.8286
# Epoch 27/100
# 6583/6583 [==============================] - 10s 1ms/step - loss: 0.3681 - accuracy: 0.8297
# Epoch 28/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.3663 - accuracy: 0.8311
# Epoch 29/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.3632 - accuracy: 0.8320
# Epoch 30/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.3644 - accuracy: 0.8314
# Epoch 31/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.3611 - accuracy: 0.8333
# Epoch 32/100
# 6583/6583 [==============================] - 10s 2ms/step - loss: 0.3589 - accuracy: 0.8353
# Epoch 33/100
# 6583/6583 [==============================] - 10s 2ms/step - loss: 0.3572 - accuracy: 0.8356
# Epoch 34/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.3566 - accuracy: 0.8351
# Epoch 35/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.3545 - accuracy: 0.8379
# Epoch 36/100
# 6583/6583 [==============================] - 10s 2ms/step - loss: 0.3534 - accuracy: 0.8368
# Epoch 37/100
# 6583/6583 [==============================] - 10s 2ms/step - loss: 0.3524 - accuracy: 0.8378
# Epoch 38/100
# 6583/6583 [==============================] - 10s 2ms/step - loss: 0.3520 - accuracy: 0.8394
# Epoch 39/100
# 6583/6583 [==============================] - 10s 2ms/step - loss: 0.3505 - accuracy: 0.8400
# Epoch 40/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.3493 - accuracy: 0.8405
# Epoch 41/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.3473 - accuracy: 0.8407
# Epoch 42/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.3471 - accuracy: 0.8401
# Epoch 43/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.3451 - accuracy: 0.8420
# Epoch 44/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.3443 - accuracy: 0.8433
# Epoch 45/100
# 6583/6583 [==============================] - 10s 2ms/step - loss: 0.3436 - accuracy: 0.8421
# Epoch 46/100
# 6583/6583 [==============================] - 10s 2ms/step - loss: 0.3424 - accuracy: 0.8440
# Epoch 47/100
# 6583/6583 [==============================] - 10s 2ms/step - loss: 0.3418 - accuracy: 0.8440
# Epoch 48/100
# 6583/6583 [==============================] - 12s 2ms/step - loss: 0.3406 - accuracy: 0.8449
# Epoch 49/100
# 6583/6583 [==============================] - 10s 1ms/step - loss: 0.3393 - accuracy: 0.8452
# Epoch 50/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.3385 - accuracy: 0.8448
# Epoch 51/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.3371 - accuracy: 0.8465
# Epoch 52/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.3358 - accuracy: 0.8469
# Epoch 53/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.3356 - accuracy: 0.8458
# Epoch 54/100
# 6583/6583 [==============================] - 10s 2ms/step - loss: 0.3353 - accuracy: 0.8462
# Epoch 55/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.3336 - accuracy: 0.8494
# Epoch 56/100
# 6583/6583 [==============================] - 12s 2ms/step - loss: 0.3327 - accuracy: 0.8480
# Epoch 57/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.3315 - accuracy: 0.8479
# Epoch 58/100
# 6583/6583 [==============================] - 12s 2ms/step - loss: 0.3301 - accuracy: 0.8497
# Epoch 59/100
# 6583/6583 [==============================] - 15s 2ms/step - loss: 0.3287 - accuracy: 0.8517
# Epoch 60/100
# 6583/6583 [==============================] - 12s 2ms/step - loss: 0.3290 - accuracy: 0.8502
# Epoch 61/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.3288 - accuracy: 0.8522
# Epoch 62/100
# 6583/6583 [==============================] - 10s 2ms/step - loss: 0.3284 - accuracy: 0.8522
# Epoch 63/100
# 6583/6583 [==============================] - 13s 2ms/step - loss: 0.3281 - accuracy: 0.8512
# Epoch 64/100
# 6583/6583 [==============================] - 13s 2ms/step - loss: 0.3270 - accuracy: 0.8520
# Epoch 65/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.3257 - accuracy: 0.8539
# Epoch 66/100
# 6583/6583 [==============================] - 13s 2ms/step - loss: 0.3257 - accuracy: 0.8531
# Epoch 67/100
# 6583/6583 [==============================] - 12s 2ms/step - loss: 0.3243 - accuracy: 0.8531
# Epoch 68/100
# 6583/6583 [==============================] - 15s 2ms/step - loss: 0.3246 - accuracy: 0.8532
# Epoch 69/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.3241 - accuracy: 0.8552
# Epoch 70/100
# 6583/6583 [==============================] - 10s 2ms/step - loss: 0.3237 - accuracy: 0.8552
# Epoch 71/100
# 6583/6583 [==============================] - 10s 1ms/step - loss: 0.3226 - accuracy: 0.8536
# Epoch 72/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.3213 - accuracy: 0.8558
# Epoch 73/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.3216 - accuracy: 0.8555
# Epoch 74/100
# 6583/6583 [==============================] - 10s 2ms/step - loss: 0.3213 - accuracy: 0.8549
# Epoch 75/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.3204 - accuracy: 0.8557
# Epoch 76/100
# 6583/6583 [==============================] - 10s 1ms/step - loss: 0.3196 - accuracy: 0.8560
# Epoch 77/100
# 6583/6583 [==============================] - 10s 1ms/step - loss: 0.3211 - accuracy: 0.8551
# Epoch 78/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.3194 - accuracy: 0.8564
# Epoch 79/100
# 6583/6583 [==============================] - 10s 2ms/step - loss: 0.3189 - accuracy: 0.8553
# Epoch 80/100
# 6583/6583 [==============================] - 10s 1ms/step - loss: 0.3174 - accuracy: 0.8562
# Epoch 81/100
# 6583/6583 [==============================] - 10s 2ms/step - loss: 0.3177 - accuracy: 0.8568
# Epoch 82/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.3168 - accuracy: 0.8576
# Epoch 83/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.3172 - accuracy: 0.8568
# Epoch 84/100
# 6583/6583 [==============================] - 10s 2ms/step - loss: 0.3159 - accuracy: 0.8582
# Epoch 85/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.3158 - accuracy: 0.8575
# Epoch 86/100
# 6583/6583 [==============================] - 10s 2ms/step - loss: 0.3142 - accuracy: 0.8572
# Epoch 87/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.3158 - accuracy: 0.8571
# Epoch 88/100
# 6583/6583 [==============================] - 10s 1ms/step - loss: 0.3149 - accuracy: 0.8585
# Epoch 89/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.3139 - accuracy: 0.8600
# Epoch 90/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.3132 - accuracy: 0.8589
# Epoch 91/100
# 6583/6583 [==============================] - 7s 1ms/step - loss: 0.3137 - accuracy: 0.8584
# Epoch 92/100
# 6583/6583 [==============================] - 7s 1ms/step - loss: 0.3128 - accuracy: 0.8596
# Epoch 93/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.3114 - accuracy: 0.8601
# Epoch 94/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.3129 - accuracy: 0.8605
# Epoch 95/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.3110 - accuracy: 0.8603
# Epoch 96/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.3104 - accuracy: 0.8598
# Epoch 97/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.3118 - accuracy: 0.8601
# Epoch 98/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.3108 - accuracy: 0.8604
# Epoch 99/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.3109 - accuracy: 0.8602
# Epoch 100/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.3100 - accuracy: 0.8613
# 129/129 [==============================] - 0s 845us/step
# Accuracy: 0.793
# Precision: 0.286
# Recall: 0.507
# Fscore: 0.365
# AUC: 0.669
#
# Confusion matrix:
# Predicted     0    1   All
# True
# 0          3022  613  3635
# 1           238  245   483
# All        3260  858  4118

# %% [markdown]
# ### Models comparison

# %%
# Confusion matrix comaprison
dict ={'indicator': ['TN', 'FP', 'FN', 'TP'],
       'lr': confusion_matrix(y_test, y_pred_lr).ravel(),
       'knn': confusion_matrix(y_test, y_pred_knn).ravel(),
       'svm': confusion_matrix(y_test, y_pred_svm).ravel(),
       'dt': confusion_matrix(y_test, y_pred_dt).ravel(),
       'rf': confusion_matrix(y_test, y_pred_rf).ravel(),
       'dn': confusion_matrix(y_test, y_pred_dn).ravel(),
       'xgb': confusion_matrix(y_test, y_pred_xgb).ravel()}

pd.DataFrame(dict).set_index('indicator')
# Out:
#              lr   knn   svm    dt    rf    dn   xgb
# indicator
# TN         3112  2964  3184  3321  3308  3022  3526
# FP          523   671   451   314   327   613   109
# FN          171   206   196   326   211   238   317
# TP          312   277   287   157   272   245   166

# %%
# Accuracy comparison
models=[lr, knn, sv, dt, rf, dn, lgb]
pd.Series([model.score(X_test, y_test) for model in models], index=['lr', 'svm', 'knn', 'dt', 'rf', 'dn', 'xgb'], name='Accuracy')
# Out:
# 412/412 [==============================] - 1s 1ms/step - loss: 0.5844 - accuracy: 0.7933
# lr     0.831472
# svm    0.787033
# knn    0.842885
# dt     0.844585
# rf     0.869354
# dn     0.793346
# xgb    0.896552
# Name: Accuracy, dtype: float64

# %% [markdown]
# ### 3. Inference

# %%
# Read original data
df = pd.read_csv("bank-additional-full.csv", sep=";")

# %%
# Creare prediction dataframe
df_test = pd.read_csv("y_test.csv", header=None, index_col=0)
df_test["prediction"] = y_pred_lr
df_test.rename(columns={1: "label"}, inplace=True)

# %%
# Join predictions with original data
results = df.join(df_test, how="right")

# %%
# Show results
results
# Out:
#        age           job  marital            education  default  housing  \
# 0
# 29971   31    technician   single    university.degree       no       no
# 34803   30       student   single              unknown       no       no
# 8936    34      services  married          high.school       no       no
# 23565   58     housemaid  married             basic.9y       no       no
# 9902    57       retired  married             basic.4y  unknown       no
# ...    ...           ...      ...                  ...      ...      ...
# 38367   55  entrepreneur  married  professional.course       no      yes
# 24918   52    technician  married          high.school       no      yes
# 37634   29    management   single    university.degree       no       no
# 40764   36    technician  married    university.degree       no  unknown
# 17184   28   blue-collar   single             basic.9y       no      yes
#
#           loan    contact month day_of_week  ...  previous     poutcome  \
# 0                                            ...
# 29971      yes   cellular   apr         tue  ...         0  nonexistent
# 34803       no   cellular   may         thu  ...         0  nonexistent
# 8936        no  telephone   jun         thu  ...         0  nonexistent
# 23565       no   cellular   aug         thu  ...         0  nonexistent
# 9902        no  telephone   jun         wed  ...         0  nonexistent
# ...        ...        ...   ...         ...  ...       ...          ...
# 38367       no   cellular   oct         mon  ...         0  nonexistent
# 24918       no   cellular   nov         tue  ...         0  nonexistent
# 37634       no   cellular   aug         mon  ...         0  nonexistent
# 40764  unknown   cellular   sep         thu  ...         0  nonexistent
# 17184      yes   cellular   jul         fri  ...         0  nonexistent
#
#        emp.var.rate  cons.price.idx cons.conf.idx  euribor3m  nr.employed  \
# 0
# 29971          -1.8          93.075         -47.1      1.405       5099.1
# 34803          -1.8          92.893         -46.2      1.266       5099.1
# 8936            1.4          94.465         -41.8      4.866       5228.1
# 23565           1.4          93.444         -36.1      4.962       5228.1
# 9902            1.4          94.465         -41.8      4.959       5228.1
# ...             ...             ...           ...        ...          ...
# 38367          -3.4          92.431         -26.9      0.739       5017.5
# 24918          -0.1          93.200         -42.0      4.153       5195.8
# 37634          -2.9          92.201         -31.4      0.861       5076.2
# 40764          -1.1          94.199         -37.5      0.879       4963.6
# 17184           1.4          93.918         -42.7      4.962       5228.1
#
#          y  label  prediction
# 0
# 29971  yes      1           1
# 34803   no      0           1
# 8936    no      0           0
# 23565   no      0           0
# 9902    no      0           0
# ...    ...    ...         ...
# 38367   no      0           1
# 24918   no      0           0
# 37634   no      0           1
# 40764  yes      1           1
# 17184   no      0           0
#
# [4119 rows x 23 columns]
