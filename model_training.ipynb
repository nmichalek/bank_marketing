# %% [markdown]
# # Model training
# The goal of is to train classification model thab will predict if the client will subscrive a term deposit. I will train a few models and compare it's results:
# 1. Models training
#     * Linear Regression
#     * KNN
#     * SVM
#     * Decision Tree
#     * Random Forest
#     * XGBoost
#     * Dense Neutral Network
# 2. Results comparison
# 3. Inference

# %% [markdown]
# ### Model training

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier 
from sklearn.metrics import accuracy_score, confusion_matrix, precision_recall_fscore_support, classification_report, precision_recall_curve, roc_auc_score, plot_roc_curve
from sklearn.model_selection import validation_curve, GridSearchCV
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
import warnings
warnings.filterwarnings("ignore")

# %%
# Read prepared training and test data
X_train = pd.read_csv("X_train_oversample.csv", index_col=0, header=None).to_numpy()
X_test= pd.read_csv("X_test.csv", index_col=0, header=None).to_numpy()
y_train = pd.read_csv("y_trainoversample.csv", index_col=0, header=None).to_numpy().flatten()
y_test = pd.read_csv("y_test.csv", index_col=0, header=None).to_numpy().flatten()

# %%
# Check sizes of read data
print(f"size of X_train: {X_train.shape}")
print(f"size of X_test: {X_test.shape}")
print(f"size of y_train: {y_train.shape}")
print(f"size of y_test: {y_test.shape}")
# Out:
# size of X_train: (65826, 27)
# size of X_test: (4119, 27)
# size of y_train: (65826,)
# size of y_test: (4119,)

# %% [markdown]
# It's imporant to properly choose metrics to asses the model. For each model I'll present the following metrics:  accuracy, precision, recall, Fscore, AUC, Confusion Matrix. I do not have knowledge, what are the exact requirements of the Business Case. I will assume that it is important to predict as many customers than will subscribe the product as possible and therefore focuss on choosing model with good recall and overall accuracy.

# %%
# Prepare a function presenting results
def results(y_test, y_pred):
  print("Accuracy: {0:0.3f}".format(accuracy_score(y_test, y_pred)))
  print("Precision: {0:0.3f}".format(precision_recall_fscore_support(y_test, y_pred, pos_label=1, average="binary")[0]))
  print("Recall: {0:0.3f}".format(precision_recall_fscore_support(y_test, y_pred, pos_label=1, average="binary")[1]))
  print("Fscore: {0:0.3f}".format(precision_recall_fscore_support(y_test, y_pred, pos_label=1, average="binary")[2]))
  print("AUC: {0:0.3f}".format(roc_auc_score(y_test, y_pred)))
  print("\nConfusion matrix:")
  return pd.crosstab(y_test, y_pred, rownames=["True"], colnames=["Predicted"], margins=True)

# %% [markdown]
# ### 1.1 Logistic Regression

# %%
# Legistic Regression model training
lr = LogisticRegression(random_state=2022).fit(X_train, y_train)
y_pred_lr = lr.predict(X_test)
results(y_test, y_pred_lr)
# Out:
# Accuracy: 0.832
# Precision: 0.374
# Recall: 0.647
# Fscore: 0.474
# AUC: 0.751
#
# Confusion matrix:
# Predicted     0    1   All
# True
# 0          3112  523  3635
# 1           171  313   484
# All        3283  836  4119

# %% [markdown]
# ### 1.2 K-Nearest Neighbors

# %%
# KNN model training
knn = KNeighborsClassifier().fit(X_train, y_train)
y_pred_knn = knn.predict(X_test)
results(y_test, y_pred_knn)
# Out:
# Accuracy: 0.787
# Precision: 0.293
# Recall: 0.572
# Fscore: 0.387
# AUC: 0.694
#
# Confusion matrix:
# Predicted     0    1   All
# True
# 0          2965  670  3635
# 1           207  277   484
# All        3172  947  4119

# %% [markdown]
# ### 1.3 SVM

# %%
sv = svm.SVC(random_state=2022).fit(X_train, y_train)
y_pred_svm = sv.predict(X_test)
results(y_test, y_pred_svm)
# Out:
# Accuracy: 0.843
# Precision: 0.390
# Recall: 0.595
# Fscore: 0.471
# AUC: 0.735
#
# Confusion matrix:
# Predicted     0    1   All
# True
# 0          3184  451  3635
# 1           196  288   484
# All        3380  739  4119

# %% [markdown]
# ### 1.4 Decision Tree

# %%
# Choose depth of decision tree using greed search
dto = DecisionTreeClassifier(random_state=2022)
param_grid = {'max_depth': [5, 10, 15, 20, 25, 30, 35, 40]}
grid_tree = GridSearchCV(dto, param_grid=param_grid, cv=3, scoring=['accuracy', 'recall'], refit='recall')
grid_tree.fit(X_train, y_train)
for i in np.arange(8):
  print(f"{grid_tree.cv_results_['params'][i]}: mean test accuracy: {grid_tree.cv_results_['mean_test_accuracy'][i]:.3f}, mean test recall: {grid_tree.cv_results_['mean_test_recall'][i]:.3f}")
# Out:
# {'max_depth': 5}: mean test accuracy: 0.759, mean test recall: 0.623
# {'max_depth': 10}: mean test accuracy: 0.850, mean test recall: 0.775
# {'max_depth': 15}: mean test accuracy: 0.878, mean test recall: 0.824
# {'max_depth': 20}: mean test accuracy: 0.889, mean test recall: 0.862
# {'max_depth': 25}: mean test accuracy: 0.891, mean test recall: 0.878
# {'max_depth': 30}: mean test accuracy: 0.889, mean test recall: 0.880
# {'max_depth': 35}: mean test accuracy: 0.890, mean test recall: 0.881
# {'max_depth': 40}: mean test accuracy: 0.890, mean test recall: 0.881

# %% [markdown]
# ##### Comment
# Similar results are obtained using depth of tree 30, 35, and 40, therefore I'll choose the simplest model out of those 3- depth 30

# %%
# Train model based on chosed max_depth and score it
dt = DecisionTreeClassifier(max_depth=30, random_state=2022)
dt.fit(X_train, y_train)
y_pred_dt = dt.predict(X_test)
results(y_test, y_pred_dt)
# Out:
# Accuracy: 0.845
# Precision: 0.335
# Recall: 0.326
# Fscore: 0.331
# AUC: 0.620
#
# Confusion matrix:
# Predicted     0    1   All
# True
# 0          3321  314  3635
# 1           326  158   484
# All        3647  472  4119

# %% [markdown]
# ### 1.5 Random Forest

# %%
# Choose parameters for random forest using Grid Search
rf= RandomForestClassifier(random_state=2022)
param_grid = {'max_depth': [6, 8, 10],
              'n_estimators': [20, 50, 100]}
grid_rf = GridSearchCV(rf, param_grid=param_grid, cv=3, scoring=['accuracy', 'recall'], refit='recall')
grid_rf.fit(X_train, y_train)
for i in np.arange(9):
  print(f"{grid_rf.cv_results_['params'][i]}: mean test accuracy: {grid_rf.cv_results_['mean_test_accuracy'][i]:.3f}, mean test recall: {grid_rf.cv_results_['mean_test_recall'][i]:.3f}")
# Out:
# {'max_depth': 6, 'n_estimators': 20}: mean test accuracy: 0.766, mean test recall: 0.667
# {'max_depth': 6, 'n_estimators': 50}: mean test accuracy: 0.766, mean test recall: 0.652
# {'max_depth': 6, 'n_estimators': 100}: mean test accuracy: 0.765, mean test recall: 0.649
# {'max_depth': 8, 'n_estimators': 20}: mean test accuracy: 0.797, mean test recall: 0.699
# {'max_depth': 8, 'n_estimators': 50}: mean test accuracy: 0.792, mean test recall: 0.689
# {'max_depth': 8, 'n_estimators': 100}: mean test accuracy: 0.787, mean test recall: 0.679
# {'max_depth': 10, 'n_estimators': 20}: mean test accuracy: 0.816, mean test recall: 0.726
# {'max_depth': 10, 'n_estimators': 50}: mean test accuracy: 0.817, mean test recall: 0.728
# {'max_depth': 10, 'n_estimators': 100}: mean test accuracy: 0.815, mean test recall: 0.726

# %%
# Train model using chosen hyperparamters
rf = RandomForestClassifier(max_depth=10, n_estimators=100, random_state=2022)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)
results(y_test, y_pred_rf)
# Out:
# Accuracy: 0.870
# Precision: 0.455
# Recall: 0.556
# Fscore: 0.500
# AUC: 0.734
#
# Confusion matrix:
# Predicted     0    1   All
# True
# 0          3313  322  3635
# 1           215  269   484
# All        3528  591  4119

# %% [markdown]
# #### 1.6 LightGBoost

# %%
# Choose parameters for random forest using Grid Search
lgb = LGBMClassifier(random_state=2022, n_jobs=-1)
param_grid = {'max_depth': [3, 5, 7, 10, 20],
              'n_estimators': [100, 200, 300],
              'learning_rate': [0.1, 0.2, 0.3]}
grid_lgb = GridSearchCV(lgb, param_grid=param_grid, cv=3, scoring=['accuracy', 'recall'], refit='recall')
grid_lgb.fit(X_train, y_train)
grid_lgb.best_params_
# Out:
# {'learning_rate': 0.3, 'max_depth': 20, 'n_estimators': 300}

# %%
# Train model using chosen hyperparamter
lgb = LGBMClassifier(max_depth=20, n_estimators=200, learning_rate=0.3, random_state=2022)
lgb.fit(X_train, y_train)
y_pred_lbg = lgb.predict(X_test)
results(y_test, y_pred_lbg)
# Out:
# Accuracy: 0.893
# Precision: 0.584
# Recall: 0.324
# Fscore: 0.417
# AUC: 0.647
#
# Confusion matrix:
# Predicted     0    1   All
# True
# 0          3523  112  3635
# 1           327  157   484
# All        3850  269  4119

# %%
# Train model using chosen hyperparamter
lgb = LGBMClassifier(max_depth=5, n_estimators=150, learning_rate=0.3, random_state=2022)
lgb.fit(X_train, y_train)
y_pred_xgb = lgb.predict(X_test)
results(y_test, y_pred_xgb)
# Out:
# Accuracy: 0.893
# Precision: 0.578
# Recall: 0.331
# Fscore: 0.420
# AUC: 0.649
#
# Confusion matrix:
# Predicted     0    1   All
# True
# 0          3518  117  3635
# 1           324  160   484
# All        3842  277  4119

# %% [markdown]
# #### 1.7 Dense Neural Network

# %%
def sequential_model():
  model = Sequential()
  model.add(Dense(64, activation='relu'))
  model.add(Dense(32, activation='relu'))
  model.add(Dense(16, activation='relu'))
  model.add(Dense(1, activation='sigmoid'))
  model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
  return model
 
dn = KerasClassifier(build_fn=sequential_model, epochs=100, batch_size=10, verbose=1)
dn.fit(X_train, y_train)
y_pred_dn = dn.predict(X_test).flatten()
results(y_test, y_pred_dn)
# Out:
# Epoch 1/100
# 6583/6583 [==============================] - 16s 2ms/step - loss: 0.5256 - accuracy: 0.7438
# Epoch 2/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.4996 - accuracy: 0.7590
# Epoch 3/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.4815 - accuracy: 0.7664
# Epoch 4/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.4677 - accuracy: 0.7748
# Epoch 5/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.4554 - accuracy: 0.7809
# Epoch 6/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.4441 - accuracy: 0.7873
# Epoch 7/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.4354 - accuracy: 0.7909
# Epoch 8/100
# 6583/6583 [==============================] - 10s 2ms/step - loss: 0.4276 - accuracy: 0.7941
# Epoch 9/100
# 6583/6583 [==============================] - 10s 1ms/step - loss: 0.4209 - accuracy: 0.7997
# Epoch 10/100
# 6583/6583 [==============================] - 10s 2ms/step - loss: 0.4134 - accuracy: 0.8048
# Epoch 11/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.4072 - accuracy: 0.8084
# Epoch 12/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.4014 - accuracy: 0.8101
# Epoch 13/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.3965 - accuracy: 0.8147
# Epoch 14/100
# 6583/6583 [==============================] - 7s 1ms/step - loss: 0.3920 - accuracy: 0.8175
# Epoch 15/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.3883 - accuracy: 0.8200
# Epoch 16/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.3846 - accuracy: 0.8224
# Epoch 17/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.3816 - accuracy: 0.8239
# Epoch 18/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.3782 - accuracy: 0.8237
# Epoch 19/100
# 6583/6583 [==============================] - 10s 2ms/step - loss: 0.3752 - accuracy: 0.8270
# Epoch 20/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.3728 - accuracy: 0.8285
# Epoch 21/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.3710 - accuracy: 0.8299
# Epoch 22/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.3676 - accuracy: 0.8307
# Epoch 23/100
# 6583/6583 [==============================] - 10s 2ms/step - loss: 0.3660 - accuracy: 0.8330
# Epoch 24/100
# 6583/6583 [==============================] - 10s 2ms/step - loss: 0.3635 - accuracy: 0.8335
# Epoch 25/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.3620 - accuracy: 0.8350
# Epoch 26/100
# 6583/6583 [==============================] - 12s 2ms/step - loss: 0.3590 - accuracy: 0.8358
# Epoch 27/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.3572 - accuracy: 0.8380
# Epoch 28/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.3558 - accuracy: 0.8372
# Epoch 29/100
# 6583/6583 [==============================] - 10s 2ms/step - loss: 0.3540 - accuracy: 0.8383
# Epoch 30/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.3516 - accuracy: 0.8403
# Epoch 31/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.3496 - accuracy: 0.8416
# Epoch 32/100
# 6583/6583 [==============================] - 10s 2ms/step - loss: 0.3482 - accuracy: 0.8426
# Epoch 33/100
# 6583/6583 [==============================] - 13s 2ms/step - loss: 0.3471 - accuracy: 0.8428
# Epoch 34/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.3457 - accuracy: 0.8428
# Epoch 35/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.3445 - accuracy: 0.8440
# Epoch 36/100
# 6583/6583 [==============================] - 12s 2ms/step - loss: 0.3430 - accuracy: 0.8441
# Epoch 37/100
# 6583/6583 [==============================] - 16s 2ms/step - loss: 0.3408 - accuracy: 0.8458
# Epoch 38/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.3395 - accuracy: 0.8458
# Epoch 39/100
# 6583/6583 [==============================] - 15s 2ms/step - loss: 0.3388 - accuracy: 0.8468
# Epoch 40/100
# 6583/6583 [==============================] - 10s 1ms/step - loss: 0.3386 - accuracy: 0.8469
# Epoch 41/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.3376 - accuracy: 0.8475
# Epoch 42/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.3359 - accuracy: 0.8488
# Epoch 43/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.3348 - accuracy: 0.8491
# Epoch 44/100
# 6583/6583 [==============================] - 7s 1ms/step - loss: 0.3339 - accuracy: 0.8501
# Epoch 45/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.3320 - accuracy: 0.8504
# Epoch 46/100
# 6583/6583 [==============================] - 10s 2ms/step - loss: 0.3320 - accuracy: 0.8505
# Epoch 47/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.3311 - accuracy: 0.8514
# Epoch 48/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.3287 - accuracy: 0.8532
# Epoch 49/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.3289 - accuracy: 0.8520
# Epoch 50/100
# 6583/6583 [==============================] - 10s 2ms/step - loss: 0.3280 - accuracy: 0.8519
# Epoch 51/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.3276 - accuracy: 0.8529
# Epoch 52/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.3263 - accuracy: 0.8533
# Epoch 53/100
# 6583/6583 [==============================] - 7s 1ms/step - loss: 0.3252 - accuracy: 0.8539
# Epoch 54/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.3247 - accuracy: 0.8539
# Epoch 55/100
# 6583/6583 [==============================] - 10s 1ms/step - loss: 0.3227 - accuracy: 0.8545
# Epoch 56/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.3239 - accuracy: 0.8548
# Epoch 57/100
# 6583/6583 [==============================] - 7s 1ms/step - loss: 0.3219 - accuracy: 0.8558
# Epoch 58/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.3207 - accuracy: 0.8562
# Epoch 59/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.3206 - accuracy: 0.8558
# Epoch 60/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.3198 - accuracy: 0.8562
# Epoch 61/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.3189 - accuracy: 0.8566
# Epoch 62/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.3191 - accuracy: 0.8568
# Epoch 63/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.3168 - accuracy: 0.8582
# Epoch 64/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.3178 - accuracy: 0.8588
# Epoch 65/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.3167 - accuracy: 0.8591
# Epoch 66/100
# 6583/6583 [==============================] - 10s 2ms/step - loss: 0.3172 - accuracy: 0.8579
# Epoch 67/100
# 6583/6583 [==============================] - 10s 2ms/step - loss: 0.3149 - accuracy: 0.8585
# Epoch 68/100
# 6583/6583 [==============================] - 10s 2ms/step - loss: 0.3145 - accuracy: 0.8595
# Epoch 69/100
# 6583/6583 [==============================] - 7s 1ms/step - loss: 0.3137 - accuracy: 0.8594
# Epoch 70/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.3138 - accuracy: 0.8580
# Epoch 71/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.3132 - accuracy: 0.8593
# Epoch 72/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.3123 - accuracy: 0.8605
# Epoch 73/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.3112 - accuracy: 0.8612
# Epoch 74/100
# 6583/6583 [==============================] - 10s 2ms/step - loss: 0.3110 - accuracy: 0.8605
# Epoch 75/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.3093 - accuracy: 0.8630
# Epoch 76/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.3108 - accuracy: 0.8607
# Epoch 77/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.3108 - accuracy: 0.8604
# Epoch 78/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.3089 - accuracy: 0.8616
# Epoch 79/100
# 6583/6583 [==============================] - 10s 2ms/step - loss: 0.3093 - accuracy: 0.8617
# Epoch 80/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.3077 - accuracy: 0.8613
# Epoch 81/100
# 6583/6583 [==============================] - 10s 1ms/step - loss: 0.3071 - accuracy: 0.8630
# Epoch 82/100
# 6583/6583 [==============================] - 9s 1ms/step - loss: 0.3078 - accuracy: 0.8621
# Epoch 83/100
# 6583/6583 [==============================] - 11s 2ms/step - loss: 0.3066 - accuracy: 0.8625
# Epoch 84/100
# 6583/6583 [==============================] - 10s 1ms/step - loss: 0.3064 - accuracy: 0.8633
# Epoch 85/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.3049 - accuracy: 0.8636
# Epoch 86/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.3052 - accuracy: 0.8633
# Epoch 87/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.3052 - accuracy: 0.8639
# Epoch 88/100
# 6583/6583 [==============================] - 7s 1ms/step - loss: 0.3059 - accuracy: 0.8635
# Epoch 89/100
# 6583/6583 [==============================] - 7s 1ms/step - loss: 0.3037 - accuracy: 0.8637
# Epoch 90/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.3042 - accuracy: 0.8642
# Epoch 91/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.3030 - accuracy: 0.8642
# Epoch 92/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.3030 - accuracy: 0.8650
# Epoch 93/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.3020 - accuracy: 0.8650
# Epoch 94/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.3018 - accuracy: 0.8666
# Epoch 95/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.3010 - accuracy: 0.8640
# Epoch 96/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.3016 - accuracy: 0.8667
# Epoch 97/100
# 6583/6583 [==============================] - 7s 1ms/step - loss: 0.3015 - accuracy: 0.8657
# Epoch 98/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.2996 - accuracy: 0.8660
# Epoch 99/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.3005 - accuracy: 0.8662
# Epoch 100/100
# 6583/6583 [==============================] - 8s 1ms/step - loss: 0.3001 - accuracy: 0.8659
# 129/129 [==============================] - 0s 773us/step
# Accuracy: 0.759
# Precision: 0.253
# Recall: 0.537
# Fscore: 0.344
# AUC: 0.663
#
# Confusion matrix:
# Predicted     0     1   All
# True
# 0          2867   768  3635
# 1           224   260   484
# All        3091  1028  4119

# %% [markdown]
# ### Models comparison

# %%
# Confusion matrix comaprison
dict ={'indicator': ['TN', 'FP', 'FN', 'TP'],
       'lr': confusion_matrix(y_test, y_pred_lr).ravel(),
       'knn': confusion_matrix(y_test, y_pred_knn).ravel(),
       'svm': confusion_matrix(y_test, y_pred_svm).ravel(),
       'dt': confusion_matrix(y_test, y_pred_dt).ravel(),
       'rf': confusion_matrix(y_test, y_pred_rf).ravel(),
       'dn': confusion_matrix(y_test, y_pred_dn).ravel(),
       'xgb': confusion_matrix(y_test, y_pred_xgb).ravel()}

pd.DataFrame(dict).set_index('indicator')
# Out:
#              lr   knn   svm    dt    rf    dn   xgb
# indicator
# TN         3112  2965  3184  3321  3313  2867  3518
# FP          523   670   451   314   322   768   117
# FN          171   207   196   326   215   224   324
# TP          313   277   288   158   269   260   160

# %%
# Accuracy comparison
models=[lr, knn, sv, dt, rf, dn, lgb]
pd.Series([model.score(X_test, y_test) for model in models], index=['lr', 'svm', 'knn', 'dt', 'rf', 'dn', 'xgb'], name='Accuracy')
# Out:
# 412/412 [==============================] - 0s 828us/step - loss: 0.6571 - accuracy: 0.7592
# lr     0.831513
# svm    0.787084
# knn    0.842923
# dt     0.844622
# rf     0.869629
# dn     0.759165
# xgb    0.892935
# Name: Accuracy, dtype: float64

# %% [markdown]
# ### 3. Inference

# %%
# Read original data
df = pd.read_csv("bank-additional-full.csv", sep=";")

# %%
# Creare prediction dataframe
df_test = pd.read_csv("y_test.csv", header=None, index_col=0)
df_test["prediction"] = y_pred_lr
df_test.rename(columns={1: "label"}, inplace=True)

# %%
# Join predictions with original data
df_results = df.join(df_test, how="right")

# %%
# Show results
df_results
# Out:
#        age           job  marital            education  default  housing  \
# 0
# 29971   31    technician   single    university.degree       no       no
# 34803   30       student   single              unknown       no       no
# 8936    34      services  married          high.school       no       no
# 23565   58     housemaid  married             basic.9y       no       no
# 9902    57       retired  married             basic.4y  unknown       no
# ...    ...           ...      ...                  ...      ...      ...
# 38367   55  entrepreneur  married  professional.course       no      yes
# 24918   52    technician  married          high.school       no      yes
# 37634   29    management   single    university.degree       no       no
# 40764   36    technician  married    university.degree       no  unknown
# 17184   28   blue-collar   single             basic.9y       no      yes
#
#           loan    contact month day_of_week  ...  previous     poutcome  \
# 0                                            ...
# 29971      yes   cellular   apr         tue  ...         0  nonexistent
# 34803       no   cellular   may         thu  ...         0  nonexistent
# 8936        no  telephone   jun         thu  ...         0  nonexistent
# 23565       no   cellular   aug         thu  ...         0  nonexistent
# 9902        no  telephone   jun         wed  ...         0  nonexistent
# ...        ...        ...   ...         ...  ...       ...          ...
# 38367       no   cellular   oct         mon  ...         0  nonexistent
# 24918       no   cellular   nov         tue  ...         0  nonexistent
# 37634       no   cellular   aug         mon  ...         0  nonexistent
# 40764  unknown   cellular   sep         thu  ...         0  nonexistent
# 17184      yes   cellular   jul         fri  ...         0  nonexistent
#
#        emp.var.rate  cons.price.idx cons.conf.idx  euribor3m  nr.employed  \
# 0
# 29971          -1.8          93.075         -47.1      1.405       5099.1
# 34803          -1.8          92.893         -46.2      1.266       5099.1
# 8936            1.4          94.465         -41.8      4.866       5228.1
# 23565           1.4          93.444         -36.1      4.962       5228.1
# 9902            1.4          94.465         -41.8      4.959       5228.1
# ...             ...             ...           ...        ...          ...
# 38367          -3.4          92.431         -26.9      0.739       5017.5
# 24918          -0.1          93.200         -42.0      4.153       5195.8
# 37634          -2.9          92.201         -31.4      0.861       5076.2
# 40764          -1.1          94.199         -37.5      0.879       4963.6
# 17184           1.4          93.918         -42.7      4.962       5228.1
#
#          y  label  prediction
# 0
# 29971  yes      1           1
# 34803   no      0           1
# 8936    no      0           0
# 23565   no      0           0
# 9902    no      0           0
# ...    ...    ...         ...
# 38367   no      0           1
# 24918   no      0           0
# 37634   no      0           1
# 40764  yes      1           1
# 17184   no      0           0
#
# [4119 rows x 23 columns]
